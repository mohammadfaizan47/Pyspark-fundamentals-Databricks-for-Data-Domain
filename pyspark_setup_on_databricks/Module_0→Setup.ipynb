# %% [markdown]
# #### Ex 1→ Install PySpark locally and verify it.

# %%
# Install Pyspark
# pip install pyspark

# Verify in Python
import pyspark
print(pyspark.__version__)
# Out:
# 4.1.0

# %% [markdown]
# #### Ex 2→ Create a SparkSession with app name and master config

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
                    .appName("MyFirstApp") \
                    .getOrCreate()

print(spark)
# Out:
# <pyspark.sql.connect.session.SparkSession object at 0xff1584916240>

# %% [markdown]
# #### Ex 3→ Set Spark config options (e.g.,executor memory)

# %%
from pyspark.sql import SparkSession

# Option 1: Set during creation
spark = SparkSession.builder \
    .appName("ConfigDemo") \
    .config("spark.sql.shuffle.partitions", "50") \
    .getOrCreate()

# View a config value
print(spark.conf.get("spark.sql.shuffle.partitions"))
# Out:
# auto
